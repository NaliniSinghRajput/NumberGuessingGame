# %%
balls = 9

print("I have a certain number of balls!, can you guess how many?")


while True:
    
    x = int(input("Take a guess: "))
    
    if x > 9:
        print("Try again, go lower this time!")
        
    elif x < 9:
        print("Try again, go higher this time!")
    
         
    else:
        print("You nailed it!")
        break
# Out:
# I have a certain number of balls!, can you guess how many?
# Take a guess:  7
# Try again, go higher this time!
# Take a guess:  9
# You nailed it!
